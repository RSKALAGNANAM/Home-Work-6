# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Even though I have done a "pip" install of owm on my laptop, I am importing it here because 
# the computer on which this will be tested may or may not have owm installed.

import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
# We want to pick cities such that we get a good distribution based on Latitude
# Therefore, I have defined 8 sections of Latitude; each one 20 degrees apart except when we go 
# further North or South towards the poles
# I am letting the program pick up as many as 200 stations within each of these ranges

# Define 8 lists to hold eight separate Latitude/Longitude 

lat_lngs_1 = []
lat_lngs_2 = []
lat_lngs_3 = []
lat_lngs_4 = []
lat_lngs_5 = []
lat_lngs_6 = []
lat_lngs_7 = []
lat_lngs_8 = []
lat_lngs_9 = []
lat_lngs_10 = []
lat_lngs_11 = []
lat_lngs_12 = []
cities = []

# Create a set of random lat and lng combinations

lats_1 = np.random.uniform(low=-90.000, high=-60.000, size=200)
lats_2 = np.random.uniform(low=-60.000, high=-40.000, size=200)
lats_3 = np.random.uniform(low=-40.000, high=-20.000, size=200)
lats_4 = np.random.uniform(low=-20.000, high=-10.000, size=200)
lats_5 = np.random.uniform(low=-10.000, high=-5.000, size=200)
lats_6 = np.random.uniform(low=-5.000, high=0.000, size=200)
lats_7 = np.random.uniform(low= 0.000, high=5.000, size=200)
lats_8 = np.random.uniform(low= 5.000, high=10.000, size=200)
lats_9 = np.random.uniform(low= 10.000, high=20.000, size=200)
lats_10 = np.random.uniform(low= 20.00, high=40.000, size=200)
lats_11 = np.random.uniform(low= 40.00, high=60.000, size=200)
lats_12 = np.random.uniform(low= 60.00, high=90.000, size=200)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Zip the eight sets of Latitude/Longitude pairs; these will be used for locating cities

lat_lngs_1 = zip(lats_1, lngs)
lat_lngs_2 = zip(lats_2, lngs)
lat_lngs_3 = zip(lats_3, lngs)
lat_lngs_4 = zip(lats_4, lngs)
lat_lngs_5 = zip(lats_5, lngs)
lat_lngs_6 = zip(lats_6, lngs)
lat_lngs_7 = zip(lats_7, lngs)
lat_lngs_8 = zip(lats_8, lngs)
lat_lngs_9 = zip(lats_9, lngs)
lat_lngs_10 = zip(lats_10, lngs)
lat_lngs_11 = zip(lats_11, lngs)
lat_lngs_12 = zip(lats_12, lngs)

# Identify nearest city for each lat, lng combination for each of the 8 sets defined above
# and add the city to the list of cities provided the city is not already part of it
# The risk of doing this is sometimes we may eliminate another city with the same name even though
# it is located elsewhere in the world (example, St. Petersburg in Florida and Russia) unless these 
# are spelled "slightly" differently

for lat_lng in lat_lngs_1:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_2:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
for lat_lng in lat_lngs_3:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_4:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
for lat_lng in lat_lngs_5:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_6:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
for lat_lng in lat_lngs_7:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
for lat_lng in lat_lngs_8:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_9:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_10:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
for lat_lng in lat_lngs_11:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

for lat_lng in lat_lngs_12:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print("Number of cities picked randomly = " + str(len(cities)))
# Out:
# Number of cities picked randomly = 924

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set up a Dataframe to collect data only for the fields as required. 
# These are city, cloudiiness, country, date, humidity, lat, lng, max temp and wind speed

city = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

#Define "settings" to pass on the api_key through
settings = {"units":"imperial","appid": api_key}

#Set up a loop to go through and fetch the data
# Make sure to have code for exception handling

# Also keep a count of how many cities did not have data
city_count_without_data = 0
record_count = 0

for i in range(len(cities)):
    record_count = record_count + 1
    if (record_count % 50 == 0):
        print("Going to sleep. Will resume in 60 seconds.")
        time.sleep(60)    
    print(f"Processing Record {i+1} for: {cities[i]}")
    try:   
        city_weather_response = owm.get_current(cities[i], **settings)
    except:
        print(f"Looks like Data does not exist for: {cities[i]}.")
        city_count_without_data = city_count_without_data + 1
        continue
    city.append(city_weather_response["name"])
    cloudiness.append(city_weather_response["clouds"]["all"])
    country.append(city_weather_response["sys"]["country"])
    date.append(city_weather_response["dt"])
    humidity.append(city_weather_response["main"]["humidity"])
    lat.append(city_weather_response["coord"]["lat"])
    lng.append(city_weather_response["coord"]["lon"])
    max_temp.append(city_weather_response["main"]["temp_max"])
    wind_speed.append(city_weather_response["wind"]["speed"])
 

   
print("\nNumber of cities that did not have data =" + str(city_count_without_data))
# Out:
# Processing Record 1 for: new norfolk
# Processing Record 2 for: ushuaia
# Processing Record 3 for: albany
# Processing Record 4 for: hermanus
# Processing Record 5 for: bluff
# Processing Record 6 for: punta arenas
# Processing Record 7 for: rikitea
# Processing Record 8 for: taolanaro
# Looks like Data does not exist for: taolanaro.
# Processing Record 9 for: busselton
# Processing Record 10 for: bredasdorp
# Processing Record 11 for: cape town
# Processing Record 12 for: chuy
# Processing Record 13 for: port alfred
# Processing Record 14 for: hobart
# Processing Record 15 for: mataura
# Processing Record 16 for: vaini
# Processing Record 17 for: east london
# Processing Record 18 for: kruisfontein
# Processing Record 19 for: saint-philippe
# Processing Record 20 for: kaitangata
# Processing Record 21 for: avarua
# Processing Record 22 for: mar del plata
# Processing Record 23 for: port elizabeth
# Processing Record 24 for: port lincoln
# Processing Record 25 for: rawson
# Processing Record 26 for: tuatapere
# Processing Record 27 for: souillac
# Processing Record 28 for: arraial do cabo
# Processing Record 29 for: plettenberg bay
# Processing Record 30 for: esperance
# Processing Record 31 for: jamestown
# Processing Record 32 for: tsihombe
# Looks like Data does not exist for: tsihombe.
# Processing Record 33 for: castro
# Processing Record 34 for: ulladulla
# Processing Record 35 for: rio gallegos
# Processing Record 36 for: coihaique
# Processing Record 37 for: rocha
# Processing Record 38 for: te anau
# Processing Record 39 for: cidreira
# Processing Record 40 for: mahebourg
# Processing Record 41 for: trelew
# Processing Record 42 for: portland
# Processing Record 43 for: waipawa
# Processing Record 44 for: southbridge
# Processing Record 45 for: ranfurly
# Processing Record 46 for: umzimvubu
# Looks like Data does not exist for: umzimvubu.
# Processing Record 47 for: christchurch
# Processing Record 48 for: saldanha
# Processing Record 49 for: yulara
# Going to sleep. Will resume in 60 seconds.
# Processing Record 50 for: santiago del estero
# Processing Record 51 for: hamilton
# Processing Record 52 for: lebu
# Processing Record 53 for: bell ville
# Processing Record 54 for: nelson bay
# Processing Record 55 for: grand river south east
# Looks like Data does not exist for: grand river south east.
# Processing Record 56 for: byron bay
# Processing Record 57 for: geraldton
# Processing Record 58 for: bambous virieux
# Processing Record 59 for: oudtshoorn
# Processing Record 60 for: carnarvon
# Processing Record 61 for: miranda
# Processing Record 62 for: caravelas
# Processing Record 63 for: okakarara
# Processing Record 64 for: tsienyane
# Looks like Data does not exist for: tsienyane.
# Processing Record 65 for: broome
# Processing Record 66 for: lambare
# Processing Record 67 for: koumac
# Processing Record 68 for: walvis bay
# Processing Record 69 for: maltahohe
# Processing Record 70 for: broken hill
# Processing Record 71 for: beloha
# Processing Record 72 for: whyalla
# Processing Record 73 for: doctor pedro p. pena
# Looks like Data does not exist for: doctor pedro p. pena.
# Processing Record 74 for: khorixas
# Processing Record 75 for: marcona
# Looks like Data does not exist for: marcona.
# Processing Record 76 for: noumea
# Processing Record 77 for: amboasary
# Processing Record 78 for: neuquen
# Processing Record 79 for: coquimbo
# Processing Record 80 for: pisco
# Processing Record 81 for: bengkulu
# Looks like Data does not exist for: bengkulu.
# Processing Record 82 for: avera
# Processing Record 83 for: le port
# Processing Record 84 for: sawtell
# Processing Record 85 for: venado tuerto
# Processing Record 86 for: tobane
# Processing Record 87 for: tumut
# Processing Record 88 for: salta
# Processing Record 89 for: alice springs
# Processing Record 90 for: ngunguru
# Processing Record 91 for: isangel
# Processing Record 92 for: vao
# Processing Record 93 for: port macquarie
# Processing Record 94 for: victor harbor
# Processing Record 95 for: alofi
# Processing Record 96 for: villarrica
# Processing Record 97 for: ancud
# Processing Record 98 for: saint-joseph
# Processing Record 99 for: parana
# Going to sleep. Will resume in 60 seconds.
# Processing Record 100 for: georgetown
# Processing Record 101 for: griffith
# Processing Record 102 for: bom jardim
# Processing Record 103 for: kanye
# Processing Record 104 for: laguna
# Processing Record 105 for: vilcun
# Processing Record 106 for: puerto ayora
# Processing Record 107 for: ararat
# Processing Record 108 for: northam
# Processing Record 109 for: kang
# Processing Record 110 for: villazon
# Looks like Data does not exist for: villazon.
# Processing Record 111 for: port hedland
# Processing Record 112 for: leeton
# Processing Record 113 for: vila velha
# Processing Record 114 for: roebourne
# Processing Record 115 for: hithadhoo
# Processing Record 116 for: san pedro
# Processing Record 117 for: antofagasta
# Processing Record 118 for: hervey bay
# Processing Record 119 for: beira
# Processing Record 120 for: nguiu
# Looks like Data does not exist for: nguiu.
# Processing Record 121 for: abapo
# Processing Record 122 for: waingapu
# Processing Record 123 for: asau
# Looks like Data does not exist for: asau.
# Processing Record 124 for: san julian
# Processing Record 125 for: atuona
# Processing Record 126 for: kirakira
# Processing Record 127 for: poum
# Processing Record 128 for: palabuhanratu
# Looks like Data does not exist for: palabuhanratu.
# Processing Record 129 for: kalabo
# Processing Record 130 for: boyolangu
# Processing Record 131 for: diamantino
# Processing Record 132 for: rundu
# Processing Record 133 for: mwinilunga
# Processing Record 134 for: nova olimpia
# Processing Record 135 for: opuwo
# Processing Record 136 for: ondjiva
# Processing Record 137 for: labuhan
# Processing Record 138 for: mutsamudu
# Looks like Data does not exist for: mutsamudu.
# Processing Record 139 for: pimentel
# Processing Record 140 for: mount isa
# Processing Record 141 for: angoche
# Processing Record 142 for: alyangula
# Processing Record 143 for: halalo
# Looks like Data does not exist for: halalo.
# Processing Record 144 for: rolim de moura
# Looks like Data does not exist for: rolim de moura.
# Processing Record 145 for: sao jose da coroa grande
# Processing Record 146 for: caluquembe
# Processing Record 147 for: huarmey
# Processing Record 148 for: hualmay
# Processing Record 149 for: kununurra
# Going to sleep. Will resume in 60 seconds.
# Processing Record 150 for: karratha
# Processing Record 151 for: mareeba
# Processing Record 152 for: fenoarivo
# Processing Record 153 for: putina
# Processing Record 154 for: kawalu
# Processing Record 155 for: santiago
# Processing Record 156 for: chicama
# Processing Record 157 for: morrinhos
# Processing Record 158 for: grand gaube
# Processing Record 159 for: faanui
# Processing Record 160 for: huambo
# Processing Record 161 for: antalaha
# Processing Record 162 for: ascension
# Looks like Data does not exist for: ascension.
# Processing Record 163 for: formoso do araguaia
# Looks like Data does not exist for: formoso do araguaia.
# Processing Record 164 for: gwembe
# Processing Record 165 for: cairns
# Processing Record 166 for: cap malheureux
# Processing Record 167 for: chulumani
# Processing Record 168 for: jabiru
# Looks like Data does not exist for: jabiru.
# Processing Record 169 for: galiwinku
# Looks like Data does not exist for: galiwinku.
# Processing Record 170 for: lolua
# Looks like Data does not exist for: lolua.
# Processing Record 171 for: luganville
# Processing Record 172 for: nhulunbuy
# Processing Record 173 for: victoria
# Processing Record 174 for: quatre cocos
# Processing Record 175 for: tiarei
# Processing Record 176 for: iberia
# Processing Record 177 for: san cristobal
# Processing Record 178 for: araxa
# Processing Record 179 for: vilhena
# Processing Record 180 for: ambulu
# Processing Record 181 for: janauba
# Processing Record 182 for: lalomanu
# Looks like Data does not exist for: lalomanu.
# Processing Record 183 for: port moresby
# Processing Record 184 for: macaubas
# Processing Record 185 for: sambava
# Processing Record 186 for: vila
# Processing Record 187 for: kaoma
# Processing Record 188 for: morondava
# Processing Record 189 for: vaitape
# Processing Record 190 for: mitsamiouli
# Processing Record 191 for: miandrivazo
# Processing Record 192 for: ilheus
# Processing Record 193 for: praya
# Processing Record 194 for: senanga
# Processing Record 195 for: riberalta
# Processing Record 196 for: namibe
# Processing Record 197 for: satitoa
# Looks like Data does not exist for: satitoa.
# Processing Record 198 for: kupang
# Processing Record 199 for: urubicha
# Going to sleep. Will resume in 60 seconds.
# Processing Record 200 for: belmonte
# Processing Record 201 for: sataua
# Looks like Data does not exist for: sataua.
# Processing Record 202 for: cerro de pasco
# Processing Record 203 for: honiara
# Processing Record 204 for: tingi
# Processing Record 205 for: mahina
# Processing Record 206 for: humaita
# Processing Record 207 for: bima
# Processing Record 208 for: manicore
# Processing Record 209 for: buala
# Processing Record 210 for: luau
# Processing Record 211 for: bambanglipuro
# Processing Record 212 for: mlonggo
# Processing Record 213 for: itaituba
# Processing Record 214 for: saurimo
# Processing Record 215 for: mwene-ditu
# Processing Record 216 for: kefamenanu
# Processing Record 217 for: padang
# Processing Record 218 for: jacareacanga
# Processing Record 219 for: matadi
# Processing Record 220 for: uige
# Processing Record 221 for: merauke
# Processing Record 222 for: samusu
# Looks like Data does not exist for: samusu.
# Processing Record 223 for: kilindoni
# Processing Record 224 for: vaitupu
# Looks like Data does not exist for: vaitupu.
# Processing Record 225 for: pitimbu
# Processing Record 226 for: gizo
# Processing Record 227 for: atambua
# Processing Record 228 for: batu
# Processing Record 229 for: balimo
# Looks like Data does not exist for: balimo.
# Processing Record 230 for: kiunga
# Processing Record 231 for: auki
# Processing Record 232 for: eirunepe
# Processing Record 233 for: metro
# Processing Record 234 for: tingo maria
# Processing Record 235 for: tual
# Processing Record 236 for: conceicao do araguaia
# Processing Record 237 for: hambantota
# Processing Record 238 for: katobu
# Processing Record 239 for: talara
# Processing Record 240 for: malanje
# Processing Record 241 for: porto velho
# Processing Record 242 for: pringsewu
# Processing Record 243 for: maraba
# Processing Record 244 for: kabalo
# Processing Record 245 for: popondetta
# Processing Record 246 for: pauini
# Processing Record 247 for: sidareja
# Processing Record 248 for: ipixuna
# Processing Record 249 for: morros
# Going to sleep. Will resume in 60 seconds.
# Processing Record 250 for: novo aripuana
# Processing Record 251 for: lumajang
# Processing Record 252 for: parnarama
# Processing Record 253 for: saleaula
# Looks like Data does not exist for: saleaula.
# Processing Record 254 for: kerema
# Processing Record 255 for: altos
# Processing Record 256 for: kamina
# Processing Record 257 for: micheweni
# Processing Record 258 for: pombal
# Processing Record 259 for: sumbawa
# Looks like Data does not exist for: sumbawa.
# Processing Record 260 for: mbuji-mayi
# Processing Record 261 for: cabedelo
# Processing Record 262 for: boca do acre
# Processing Record 263 for: gamba
# Processing Record 264 for: singaraja
# Processing Record 265 for: ende
# Processing Record 266 for: ariquemes
# Processing Record 267 for: maumere
# Processing Record 268 for: igaci
# Processing Record 269 for: chazuta
# Processing Record 270 for: buin
# Processing Record 271 for: mafinga
# Looks like Data does not exist for: mafinga.
# Processing Record 272 for: amahai
# Processing Record 273 for: barcelos
# Processing Record 274 for: polewali
# Processing Record 275 for: ijaki
# Looks like Data does not exist for: ijaki.
# Processing Record 276 for: sungaipenuh
# Processing Record 277 for: ilebo
# Processing Record 278 for: pontianak
# Processing Record 279 for: pangkalanbuun
# Processing Record 280 for: axim
# Processing Record 281 for: mbandaka
# Processing Record 282 for: lodja
# Processing Record 283 for: luwuk
# Processing Record 284 for: meulaboh
# Processing Record 285 for: urucara
# Processing Record 286 for: kieta
# Processing Record 287 for: nkayi
# Processing Record 288 for: brazzaville
# Processing Record 289 for: kendari
# Processing Record 290 for: barawe
# Looks like Data does not exist for: barawe.
# Processing Record 291 for: vanimo
# Processing Record 292 for: witu
# Processing Record 293 for: biak
# Processing Record 294 for: touros
# Processing Record 295 for: djambala
# Processing Record 296 for: tidore
# Looks like Data does not exist for: tidore.
# Processing Record 297 for: sampit
# Processing Record 298 for: mendahara
# Looks like Data does not exist for: mendahara.
# Processing Record 299 for: aitape
# Going to sleep. Will resume in 60 seconds.
# Processing Record 300 for: mogadishu
# Processing Record 301 for: leticia
# Processing Record 302 for: mentok
# Looks like Data does not exist for: mentok.
# Processing Record 303 for: barranca
# Processing Record 304 for: mocajuba
# Processing Record 305 for: thinadhoo
# Processing Record 306 for: coahuayana
# Processing Record 307 for: harper
# Processing Record 308 for: bolobo
# Processing Record 309 for: san patricio
# Processing Record 310 for: coari
# Processing Record 311 for: tucurui
# Processing Record 312 for: kabare
# Processing Record 313 for: lorengau
# Processing Record 314 for: viligili
# Looks like Data does not exist for: viligili.
# Processing Record 315 for: carauari
# Processing Record 316 for: sorong
# Processing Record 317 for: rungata
# Looks like Data does not exist for: rungata.
# Processing Record 318 for: nabire
# Processing Record 319 for: utiroa
# Looks like Data does not exist for: utiroa.
# Processing Record 320 for: manggar
# Processing Record 321 for: samalaeulu
# Looks like Data does not exist for: samalaeulu.
# Processing Record 322 for: puerto narino
# Processing Record 323 for: sitio novo do tocantins
# Looks like Data does not exist for: sitio novo do tocantins.
# Processing Record 324 for: careiro da varzea
# Processing Record 325 for: humberto de campos
# Processing Record 326 for: tutoia
# Processing Record 327 for: tabiauea
# Looks like Data does not exist for: tabiauea.
# Processing Record 328 for: kindu
# Processing Record 329 for: lamu
# Processing Record 330 for: kismayo
# Looks like Data does not exist for: kismayo.
# Processing Record 331 for: trairi
# Processing Record 332 for: japura
# Processing Record 333 for: martapura
# Processing Record 334 for: fonte boa
# Processing Record 335 for: takoradi
# Processing Record 336 for: palu
# Processing Record 337 for: omboue
# Processing Record 338 for: balikpapan
# Processing Record 339 for: tapaua
# Looks like Data does not exist for: tapaua.
# Processing Record 340 for: nioki
# Processing Record 341 for: caucaia
# Processing Record 342 for: matara
# Processing Record 343 for: ngorongoro
# Processing Record 344 for: ternate
# Processing Record 345 for: boa vista
# Processing Record 346 for: bontang
# Processing Record 347 for: tabou
# Processing Record 348 for: rawannawi
# Looks like Data does not exist for: rawannawi.
# Processing Record 349 for: namatanai
# Going to sleep. Will resume in 60 seconds.
# Processing Record 350 for: kudahuvadhoo
# Processing Record 351 for: sibolga
# Processing Record 352 for: bongandanga
# Processing Record 353 for: sri aman
# Processing Record 354 for: sibu
# Processing Record 355 for: oriximina
# Processing Record 356 for: impfondo
# Processing Record 357 for: basoko
# Processing Record 358 for: manado
# Processing Record 359 for: bonthe
# Processing Record 360 for: banda aceh
# Processing Record 361 for: lethem
# Processing Record 362 for: makokou
# Processing Record 363 for: berberati
# Processing Record 364 for: payakumbuh
# Processing Record 365 for: gorontalo
# Processing Record 366 for: xuddur
# Processing Record 367 for: hilo
# Processing Record 368 for: wajir
# Processing Record 369 for: yokadouma
# Processing Record 370 for: pundaguitan
# Processing Record 371 for: kapit
# Processing Record 372 for: gua musang
# Processing Record 373 for: mahadday weyne
# Looks like Data does not exist for: mahadday weyne.
# Processing Record 374 for: cumaribo
# Looks like Data does not exist for: cumaribo.
# Processing Record 375 for: kijang
# Processing Record 376 for: padilla
# Processing Record 377 for: puerto baquerizo moreno
# Processing Record 378 for: saint-georges
# Processing Record 379 for: ouesso
# Processing Record 380 for: eyl
# Processing Record 381 for: temerloh
# Processing Record 382 for: amapa
# Processing Record 383 for: yambio
# Looks like Data does not exist for: yambio.
# Processing Record 384 for: galle
# Processing Record 385 for: bandarbeyla
# Processing Record 386 for: puerto ayacucho
# Processing Record 387 for: kloulklubed
# Processing Record 388 for: manokwari
# Processing Record 389 for: weligama
# Processing Record 390 for: acapulco
# Processing Record 391 for: butaritari
# Processing Record 392 for: pemangkat
# Looks like Data does not exist for: pemangkat.
# Processing Record 393 for: langsa
# Processing Record 394 for: miraflores
# Processing Record 395 for: felidhoo
# Looks like Data does not exist for: felidhoo.
# Processing Record 396 for: miri
# Processing Record 397 for: cururupu
# Processing Record 398 for: goderich
# Processing Record 399 for: hobyo
# Going to sleep. Will resume in 60 seconds.
# Processing Record 400 for: yangambi
# Processing Record 401 for: dinsor
# Looks like Data does not exist for: dinsor.
# Processing Record 402 for: itarema
# Processing Record 403 for: mitu
# Processing Record 404 for: keningau
# Processing Record 405 for: wattegama
# Processing Record 406 for: bondo
# Processing Record 407 for: inirida
# Processing Record 408 for: mumford
# Processing Record 409 for: abonnema
# Processing Record 410 for: praia
# Processing Record 411 for: tawau
# Processing Record 412 for: tabialan
# Looks like Data does not exist for: tabialan.
# Processing Record 413 for: mongoumba
# Processing Record 414 for: totoro
# Processing Record 415 for: mahibadhoo
# Processing Record 416 for: chepareria
# Processing Record 417 for: san isidro
# Processing Record 418 for: ciudad bolivar
# Processing Record 419 for: panacan
# Processing Record 420 for: seguela
# Processing Record 421 for: upata
# Processing Record 422 for: kavaratti
# Processing Record 423 for: krabi
# Processing Record 424 for: varkkallai
# Processing Record 425 for: ouadda
# Processing Record 426 for: beyla
# Processing Record 427 for: bouna
# Processing Record 428 for: totness
# Processing Record 429 for: sarh
# Processing Record 430 for: ganassi
# Processing Record 431 for: kandy
# Processing Record 432 for: conakry
# Processing Record 433 for: port blair
# Processing Record 434 for: ngaoundere
# Processing Record 435 for: bol
# Processing Record 436 for: kalmunai
# Processing Record 437 for: satun
# Processing Record 438 for: bantogon
# Processing Record 439 for: odweyne
# Looks like Data does not exist for: odweyne.
# Processing Record 440 for: santa cruz
# Processing Record 441 for: ao luk
# Looks like Data does not exist for: ao luk.
# Processing Record 442 for: airai
# Processing Record 443 for: kibre mengist
# Processing Record 444 for: tucupita
# Processing Record 445 for: sao filipe
# Processing Record 446 for: baboua
# Looks like Data does not exist for: baboua.
# Processing Record 447 for: kavieng
# Processing Record 448 for: sabang
# Processing Record 449 for: sai buri
# Going to sleep. Will resume in 60 seconds.
# Processing Record 450 for: cravo norte
# Processing Record 451 for: bac lieu
# Looks like Data does not exist for: bac lieu.
# Processing Record 452 for: ranong
# Processing Record 453 for: puerto escondido
# Processing Record 454 for: canalete
# Processing Record 455 for: cabo san lucas
# Processing Record 456 for: cayenne
# Processing Record 457 for: malim
# Processing Record 458 for: burica
# Looks like Data does not exist for: burica.
# Processing Record 459 for: kampot
# Processing Record 460 for: pochutla
# Processing Record 461 for: gogrial
# Looks like Data does not exist for: gogrial.
# Processing Record 462 for: padmanabhapuram
# Processing Record 463 for: touba
# Processing Record 464 for: calabozo
# Processing Record 465 for: meyungs
# Looks like Data does not exist for: meyungs.
# Processing Record 466 for: beruwala
# Processing Record 467 for: bubaque
# Processing Record 468 for: dhidhdhoo
# Processing Record 469 for: phan thiet
# Processing Record 470 for: ugoofaaru
# Processing Record 471 for: kapaa
# Processing Record 472 for: makakilo city
# Processing Record 473 for: san carlos del zulia
# Processing Record 474 for: la libertad
# Processing Record 475 for: lazaro cardenas
# Processing Record 476 for: manadhoo
# Processing Record 477 for: mabaruma
# Processing Record 478 for: salinopolis
# Processing Record 479 for: carutapera
# Processing Record 480 for: zemio
# Processing Record 481 for: jijiga
# Processing Record 482 for: odienne
# Processing Record 483 for: guasdualito
# Processing Record 484 for: batticaloa
# Processing Record 485 for: bria
# Processing Record 486 for: puerto carreno
# Processing Record 487 for: tema
# Processing Record 488 for: parangan
# Processing Record 489 for: minna
# Processing Record 490 for: kota belud
# Processing Record 491 for: rio tuba
# Processing Record 492 for: culipapa
# Looks like Data does not exist for: culipapa.
# Processing Record 493 for: basay
# Processing Record 494 for: bouca
# Processing Record 495 for: champerico
# Processing Record 496 for: phan rang
# Looks like Data does not exist for: phan rang.
# Processing Record 497 for: mizan teferi
# Processing Record 498 for: sulangan
# Processing Record 499 for: charlestown
# Going to sleep. Will resume in 60 seconds.
# Processing Record 500 for: puro
# Processing Record 501 for: bougouni
# Processing Record 502 for: puerto madero
# Processing Record 503 for: codrington
# Processing Record 504 for: chumphon
# Processing Record 505 for: dudhani
# Processing Record 506 for: biltine
# Processing Record 507 for: wanning
# Processing Record 508 for: mandiana
# Processing Record 509 for: quang ngai
# Processing Record 510 for: boromo
# Processing Record 511 for: bathsheba
# Processing Record 512 for: faya
# Processing Record 513 for: kutum
# Processing Record 514 for: manambrag
# Looks like Data does not exist for: manambrag.
# Processing Record 515 for: allapalli
# Processing Record 516 for: nouakchott
# Processing Record 517 for: mathbaria
# Processing Record 518 for: saint-francois
# Processing Record 519 for: maiduguri
# Processing Record 520 for: massakory
# Processing Record 521 for: u thong
# Processing Record 522 for: san vicente
# Processing Record 523 for: berbera
# Looks like Data does not exist for: berbera.
# Processing Record 524 for: lat yao
# Processing Record 525 for: abha
# Processing Record 526 for: coulihaut
# Looks like Data does not exist for: coulihaut.
# Processing Record 527 for: kousseri
# Looks like Data does not exist for: kousseri.
# Processing Record 528 for: tzucacab
# Processing Record 529 for: dangriga
# Processing Record 530 for: teknaf
# Processing Record 531 for: pandan
# Processing Record 532 for: yangjiang
# Processing Record 533 for: sisophon
# Processing Record 534 for: aden
# Processing Record 535 for: westpunt
# Looks like Data does not exist for: westpunt.
# Processing Record 536 for: saravan
# Processing Record 537 for: dawei
# Processing Record 538 for: tecoanapa
# Processing Record 539 for: el cobre
# Processing Record 540 for: gigmoto
# Processing Record 541 for: san rafael del sur
# Processing Record 542 for: veraval
# Processing Record 543 for: constitucion
# Processing Record 544 for: paradwip
# Looks like Data does not exist for: paradwip.
# Processing Record 545 for: dicabisagan
# Processing Record 546 for: gualaco
# Processing Record 547 for: salalah
# Processing Record 548 for: the valley
# Processing Record 549 for: khon kaen
# Going to sleep. Will resume in 60 seconds.
# Processing Record 550 for: sinnamary
# Processing Record 551 for: atlautla
# Processing Record 552 for: nogales
# Processing Record 553 for: babanusah
# Looks like Data does not exist for: babanusah.
# Processing Record 554 for: dakar
# Processing Record 555 for: hosakote
# Processing Record 556 for: kangaba
# Processing Record 557 for: manati
# Processing Record 558 for: san policarpo
# Processing Record 559 for: nishihara
# Processing Record 560 for: badvel
# Processing Record 561 for: guerrero negro
# Processing Record 562 for: dong hoi
# Processing Record 563 for: nouadhibou
# Processing Record 564 for: mangrol
# Processing Record 565 for: tomatlan
# Processing Record 566 for: tuy hoa
# Processing Record 567 for: mergui
# Looks like Data does not exist for: mergui.
# Processing Record 568 for: oranjestad
# Processing Record 569 for: acajutla
# Processing Record 570 for: kalghatgi
# Processing Record 571 for: vila do maio
# Processing Record 572 for: lompoc
# Processing Record 573 for: bajil
# Processing Record 574 for: lahij
# Processing Record 575 for: porto novo
# Processing Record 576 for: nara
# Processing Record 577 for: bonao
# Processing Record 578 for: petatlan
# Processing Record 579 for: jiazi
# Processing Record 580 for: palasa
# Looks like Data does not exist for: palasa.
# Processing Record 581 for: putla
# Looks like Data does not exist for: putla.
# Processing Record 582 for: arecibo
# Processing Record 583 for: ewa beach
# Processing Record 584 for: mango
# Processing Record 585 for: san nicolas
# Processing Record 586 for: agadez
# Processing Record 587 for: aporawan
# Looks like Data does not exist for: aporawan.
# Processing Record 588 for: san joaquin
# Processing Record 589 for: kattivakkam
# Processing Record 590 for: mundo nuevo
# Processing Record 591 for: escarcega
# Processing Record 592 for: morant bay
# Processing Record 593 for: galgani
# Looks like Data does not exist for: galgani.
# Processing Record 594 for: nanakuli
# Processing Record 595 for: seoul
# Processing Record 596 for: changli
# Processing Record 597 for: alcains
# Processing Record 598 for: brownsville
# Processing Record 599 for: fortuna
# Going to sleep. Will resume in 60 seconds.
# Processing Record 600 for: sentyabrskiy
# Looks like Data does not exist for: sentyabrskiy.
# Processing Record 601 for: dwarka
# Processing Record 602 for: hasaki
# Processing Record 603 for: tezu
# Processing Record 604 for: khanna
# Processing Record 605 for: jinji
# Processing Record 606 for: azimur
# Looks like Data does not exist for: azimur.
# Processing Record 607 for: haikou
# Processing Record 608 for: taoudenni
# Processing Record 609 for: ponta do sol
# Processing Record 610 for: benghazi
# Processing Record 611 for: tubruq
# Looks like Data does not exist for: tubruq.
# Processing Record 612 for: huilong
# Processing Record 613 for: leh
# Processing Record 614 for: santa lucia
# Processing Record 615 for: lasa
# Processing Record 616 for: saint george
# Processing Record 617 for: sabha
# Processing Record 618 for: marzuq
# Processing Record 619 for: mangan
# Processing Record 620 for: yaan
# Processing Record 621 for: ishigaki
# Processing Record 622 for: buraydah
# Processing Record 623 for: olive branch
# Processing Record 624 for: dali
# Processing Record 625 for: shimoda
# Processing Record 626 for: sakakah
# Looks like Data does not exist for: sakakah.
# Processing Record 627 for: shingu
# Processing Record 628 for: along
# Processing Record 629 for: centralia
# Processing Record 630 for: prichard
# Processing Record 631 for: hami
# Processing Record 632 for: hirara
# Processing Record 633 for: huaicheng
# Processing Record 634 for: wuwei
# Processing Record 635 for: katsuura
# Processing Record 636 for: susangerd
# Processing Record 637 for: yinchuan
# Processing Record 638 for: plainview
# Processing Record 639 for: dunmore town
# Processing Record 640 for: itoman
# Processing Record 641 for: pascagoula
# Processing Record 642 for: contai
# Processing Record 643 for: torbay
# Processing Record 644 for: hurricane
# Processing Record 645 for: nirsa
# Processing Record 646 for: marrakesh
# Processing Record 647 for: kahului
# Processing Record 648 for: glasgow
# Processing Record 649 for: amantea
# Going to sleep. Will resume in 60 seconds.
# Processing Record 650 for: san quintin
# Processing Record 651 for: yazd
# Processing Record 652 for: gejiu
# Processing Record 653 for: weatherford
# Processing Record 654 for: denton
# Processing Record 655 for: marawi
# Processing Record 656 for: bhainsdehi
# Processing Record 657 for: minab
# Processing Record 658 for: half moon bay
# Processing Record 659 for: izumo
# Processing Record 660 for: nikolskoye
# Processing Record 661 for: muroto
# Processing Record 662 for: shache
# Processing Record 663 for: ojinaga
# Processing Record 664 for: pingliang
# Processing Record 665 for: johi
# Processing Record 666 for: eskasem
# Looks like Data does not exist for: eskasem.
# Processing Record 667 for: ryotsu
# Processing Record 668 for: herat
# Processing Record 669 for: todos santos
# Processing Record 670 for: liuzhou
# Processing Record 671 for: qandahar
# Looks like Data does not exist for: qandahar.
# Processing Record 672 for: cockburn town
# Processing Record 673 for: west helena
# Processing Record 674 for: sirjan
# Processing Record 675 for: creel
# Processing Record 676 for: pansemal
# Processing Record 677 for: dengfeng
# Processing Record 678 for: ribeira grande
# Processing Record 679 for: los llanos de aridane
# Processing Record 680 for: bandar-e lengeh
# Processing Record 681 for: jalu
# Processing Record 682 for: baghdad
# Processing Record 683 for: riyadh
# Processing Record 684 for: faro
# Processing Record 685 for: brigantine
# Processing Record 686 for: liberal
# Processing Record 687 for: saharsa
# Processing Record 688 for: ducheng
# Processing Record 689 for: kingsville
# Processing Record 690 for: pacific grove
# Processing Record 691 for: adrar
# Processing Record 692 for: zhenjiang
# Processing Record 693 for: gat
# Processing Record 694 for: vila franca do campo
# Processing Record 695 for: longyan
# Processing Record 696 for: jingdezhen
# Processing Record 697 for: juegang
# Processing Record 698 for: kuche
# Looks like Data does not exist for: kuche.
# Processing Record 699 for: ninghai
# Going to sleep. Will resume in 60 seconds.
# Processing Record 700 for: siderno
# Processing Record 701 for: freeport
# Processing Record 702 for: ramanuj ganj
# Processing Record 703 for: jiexiu
# Processing Record 704 for: blytheville
# Processing Record 705 for: gibara
# Processing Record 706 for: liliani
# Processing Record 707 for: abu dhabi
# Processing Record 708 for: umm lajj
# Processing Record 709 for: helong
# Processing Record 710 for: havre-saint-pierre
# Processing Record 711 for: davenda
# Processing Record 712 for: cervo
# Processing Record 713 for: thompson
# Processing Record 714 for: port hardy
# Processing Record 715 for: severo-kurilsk
# Processing Record 716 for: kondinskoye
# Processing Record 717 for: petropavlovsk-kamchatskiy
# Processing Record 718 for: kodinsk
# Processing Record 719 for: vengerovo
# Processing Record 720 for: ostroleka
# Processing Record 721 for: kichera
# Processing Record 722 for: vagur
# Processing Record 723 for: khilok
# Processing Record 724 for: pencaitland
# Processing Record 725 for: saint anthony
# Processing Record 726 for: athabasca
# Processing Record 727 for: rabo de peixe
# Processing Record 728 for: eloszallas
# Processing Record 729 for: livezile
# Processing Record 730 for: tieling
# Processing Record 731 for: yining
# Processing Record 732 for: peniche
# Processing Record 733 for: mazulskiy
# Looks like Data does not exist for: mazulskiy.
# Processing Record 734 for: louisbourg
# Looks like Data does not exist for: louisbourg.
# Processing Record 735 for: halmstad
# Processing Record 736 for: sulechow
# Processing Record 737 for: teguldet
# Processing Record 738 for: hovd
# Processing Record 739 for: zaplavnoye
# Processing Record 740 for: rock falls
# Processing Record 741 for: orlik
# Processing Record 742 for: yoichi
# Processing Record 743 for: bethel
# Processing Record 744 for: komsomolsk
# Processing Record 745 for: ayan
# Processing Record 746 for: provideniya
# Processing Record 747 for: liverpool
# Processing Record 748 for: lagoa
# Processing Record 749 for: niesky
# Going to sleep. Will resume in 60 seconds.
# Processing Record 750 for: juneau
# Processing Record 751 for: la salle
# Processing Record 752 for: marquette
# Processing Record 753 for: acheng
# Processing Record 754 for: bagdarin
# Processing Record 755 for: kholmsk
# Processing Record 756 for: shebunino
# Processing Record 757 for: eureka
# Processing Record 758 for: ust-kamchatsk
# Looks like Data does not exist for: ust-kamchatsk.
# Processing Record 759 for: poretskoye
# Processing Record 760 for: millinocket
# Processing Record 761 for: dzhida
# Processing Record 762 for: north platte
# Processing Record 763 for: senneterre
# Processing Record 764 for: kraskino
# Processing Record 765 for: neenah
# Processing Record 766 for: high level
# Processing Record 767 for: bonavista
# Processing Record 768 for: lugovoy
# Processing Record 769 for: chase
# Processing Record 770 for: zyryanskoye
# Processing Record 771 for: gannan
# Processing Record 772 for: carrick-on-suir
# Processing Record 773 for: kodiak
# Processing Record 774 for: elwood
# Processing Record 775 for: ferrandina
# Processing Record 776 for: beyneu
# Processing Record 777 for: charlottetown
# Processing Record 778 for: qaqortoq
# Processing Record 779 for: zilupe
# Processing Record 780 for: dingle
# Processing Record 781 for: kyshtovka
# Processing Record 782 for: baherden
# Processing Record 783 for: winnemucca
# Processing Record 784 for: sitka
# Processing Record 785 for: fredericton
# Processing Record 786 for: amga
# Processing Record 787 for: berezovyy
# Processing Record 788 for: kedrovyy
# Processing Record 789 for: wynyard
# Processing Record 790 for: burns lake
# Processing Record 791 for: campbell river
# Processing Record 792 for: haibowan
# Looks like Data does not exist for: haibowan.
# Processing Record 793 for: muros
# Processing Record 794 for: derzhavinsk
# Processing Record 795 for: milkovo
# Processing Record 796 for: troitskoye
# Processing Record 797 for: gorin
# Processing Record 798 for: kataysk
# Processing Record 799 for: grand centre
# Looks like Data does not exist for: grand centre.
# Going to sleep. Will resume in 60 seconds.
# Processing Record 800 for: novoilinsk
# Looks like Data does not exist for: novoilinsk.
# Processing Record 801 for: bogandinskiy
# Processing Record 802 for: toora-khem
# Processing Record 803 for: dolbeau
# Looks like Data does not exist for: dolbeau.
# Processing Record 804 for: atikokan
# Processing Record 805 for: nanortalik
# Processing Record 806 for: shubarkuduk
# Processing Record 807 for: riverton
# Processing Record 808 for: balkhash
# Processing Record 809 for: channel-port aux basques
# Processing Record 810 for: erenhot
# Processing Record 811 for: vestmannaeyjar
# Processing Record 812 for: okhotsk
# Processing Record 813 for: aksay
# Processing Record 814 for: verkhovyna
# Processing Record 815 for: bekovo
# Processing Record 816 for: kamennomostskoye
# Processing Record 817 for: banff
# Processing Record 818 for: beringovskiy
# Processing Record 819 for: galashki
# Processing Record 820 for: tasiilaq
# Processing Record 821 for: nantucket
# Processing Record 822 for: mombetsu
# Processing Record 823 for: kropotkin
# Processing Record 824 for: pervomayskoye
# Processing Record 825 for: kyra
# Looks like Data does not exist for: kyra.
# Processing Record 826 for: schela
# Processing Record 827 for: valley city
# Processing Record 828 for: plaster rock
# Processing Record 829 for: scarborough
# Processing Record 830 for: chara
# Processing Record 831 for: norden
# Processing Record 832 for: mujiayingzi
# Processing Record 833 for: ksenyevka
# Looks like Data does not exist for: ksenyevka.
# Processing Record 834 for: tongliao
# Processing Record 835 for: heishan
# Processing Record 836 for: vares
# Processing Record 837 for: charyshskoye
# Processing Record 838 for: prince rupert
# Processing Record 839 for: marshfield
# Processing Record 840 for: attawapiskat
# Looks like Data does not exist for: attawapiskat.
# Processing Record 841 for: odesskoye
# Processing Record 842 for: makat
# Processing Record 843 for: torzhok
# Processing Record 844 for: tiksi
# Processing Record 845 for: pangnirtung
# Processing Record 846 for: verkhnevilyuysk
# Processing Record 847 for: klaksvik
# Processing Record 848 for: komsomolskiy
# Processing Record 849 for: upernavik
# Going to sleep. Will resume in 60 seconds.
# Processing Record 850 for: mayo
# Processing Record 851 for: cherskiy
# Processing Record 852 for: amderma
# Looks like Data does not exist for: amderma.
# Processing Record 853 for: evensk
# Processing Record 854 for: khatanga
# Processing Record 855 for: dikson
# Processing Record 856 for: oksfjord
# Processing Record 857 for: saskylakh
# Processing Record 858 for: husavik
# Processing Record 859 for: barentsburg
# Looks like Data does not exist for: barentsburg.
# Processing Record 860 for: yellowknife
# Processing Record 861 for: illoqqortoormiut
# Looks like Data does not exist for: illoqqortoormiut.
# Processing Record 862 for: tromso
# Processing Record 863 for: havoysund
# Processing Record 864 for: talnakh
# Processing Record 865 for: sisimiut
# Processing Record 866 for: ostersund
# Processing Record 867 for: nizhniy kuranakh
# Processing Record 868 for: belushya guba
# Looks like Data does not exist for: belushya guba.
# Processing Record 869 for: qaanaaq
# Processing Record 870 for: nizhneyansk
# Looks like Data does not exist for: nizhneyansk.
# Processing Record 871 for: barrow
# Processing Record 872 for: arkhangelsk
# Processing Record 873 for: khandyga
# Processing Record 874 for: mys shmidta
# Looks like Data does not exist for: mys shmidta.
# Processing Record 875 for: bolungarvik
# Looks like Data does not exist for: bolungarvik.
# Processing Record 876 for: longyearbyen
# Processing Record 877 for: baykit
# Processing Record 878 for: tuktoyaktuk
# Processing Record 879 for: chokurdakh
# Processing Record 880 for: teya
# Processing Record 881 for: berdigestyakh
# Processing Record 882 for: vanavara
# Processing Record 883 for: ust-nera
# Processing Record 884 for: deputatskiy
# Processing Record 885 for: leshukonskoye
# Processing Record 886 for: iqaluit
# Processing Record 887 for: hay river
# Processing Record 888 for: ilulissat
# Processing Record 889 for: turukhansk
# Processing Record 890 for: zhigansk
# Processing Record 891 for: andenes
# Looks like Data does not exist for: andenes.
# Processing Record 892 for: aklavik
# Processing Record 893 for: narsaq
# Processing Record 894 for: paamiut
# Processing Record 895 for: mehamn
# Processing Record 896 for: akureyri
# Processing Record 897 for: shirokiy
# Processing Record 898 for: novoagansk
# Processing Record 899 for: vestmanna
# Going to sleep. Will resume in 60 seconds.
# Processing Record 900 for: usinsk
# Processing Record 901 for: norman wells
# Processing Record 902 for: leningradskiy
# Processing Record 903 for: urengoy
# Processing Record 904 for: anadyr
# Processing Record 905 for: salekhard
# Processing Record 906 for: zapolyarnyy
# Processing Record 907 for: muzhi
# Processing Record 908 for: lavrentiya
# Processing Record 909 for: nome
# Processing Record 910 for: college
# Processing Record 911 for: udachnyy
# Processing Record 912 for: vodnyy
# Processing Record 913 for: pevek
# Processing Record 914 for: inuvik
# Processing Record 915 for: ostrovnoy
# Processing Record 916 for: kamenka
# Processing Record 917 for: clyde river
# Processing Record 918 for: suntar
# Processing Record 919 for: kristiansund
# Processing Record 920 for: grindavik
# Processing Record 921 for: whitehorse
# Processing Record 922 for: srednekolymsk
# Processing Record 923 for: shchelyayur
# Looks like Data does not exist for: shchelyayur.
# Processing Record 924 for: povenets
#
# Number of cities that did not have data =97

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Now that we have read the data, define a dataframe to hold the data
# Call the dataframe "my_weather_df"

my_weather_df = pd.DataFrame({"City":city, "Cloudiness":cloudiness, "Country":country, "Date":date, "Humidity":humidity,"Lat":lat,"Lng":lng,"Max Temp":max_temp,"Wind Speed":wind_speed})

#Clean the DataFrame - I believe this is a good habit to form

my_weather_df.dropna(how='any')

# Get the number of records after dropping

length_after_dropna = len(my_weather_df["City"])

print("Number of records after doing a dropna() = " + str(length_after_dropna)+".")

# During one of the runs, I found that the value of himidity for a city (Iquitos) was 319 percent
# We know this is an invalid entry because the maximum is 100 percent.
# Similarly, cloudiness that is reported as percent also cannot have values above 100 percent.
# Therefore we need to delete Rows where either one of these is above 100 percent.
# Also, there are places on the Earth where temperatures can be as high as 120 to 130 degrees F
# India had such temperatures this summer

# Keep only those Rows where Humidity <= 100 percent; Cloudiness <= 100 percent and Max Temp <= 140 deg F

my_weather_df = my_weather_df.loc[my_weather_df['Humidity'] <= 100]

my_weather_df = my_weather_df.loc[my_weather_df['Cloudiness'] <= 100]

my_weather_df = my_weather_df.loc[my_weather_df['Max Temp'] <= 140]

# Get the length of the Data Frame

length_after_dropping_invalid_data = len(my_weather_df["City"])

print("Number of records after dropping invalid data = " + str(length_after_dropping_invalid_data)+".")

records_dropped = length_after_dropna - length_after_dropping_invalid_data

print("Number of records dropped due to invalid data = " + str(records_dropped)+".")


# Export the file as a csv

my_weather_df.to_csv("cities.csv", index = None, header=True)

#Display the header

my_weather_df.head()
# Out:
# Number of records after doing a dropna() = 827.
# Number of records after dropping invalid data = 826.
# Number of records dropped due to invalid data = 1.
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  New Norfolk          75      AU  1562085829        70 -42.78  147.06
# 1      Ushuaia          75      AR  1562085829        86 -54.81  -68.31
# 2       Albany          90      US  1562085714        73  42.65  -73.75
# 3     Hermanus         100      ZA  1562085830        72 -34.42   19.24
# 4        Bluff          49      AU  1562085830        82 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0     46.00        3.36
# 1     33.80        9.17
# 2     75.99        5.82
# 3     64.00       14.00
# 4     58.07        4.61

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Plot the Latitude vs. Maximum Temperature Graph
# Define the size of the plot
plt.figure(figsize=(10, 8), dpi=80)
#Define the scatter plot and its features
plt.scatter(my_weather_df['Lat'],my_weather_df['Max Temp'], marker = "o", alpha = 0.75, facecolor = "blue", edgecolors = "black")
plt.title("City Latitude vs. Max Temperature (07/02/2019 @ 1:00 PM EDT)", fontsize = 18)
plt.xlabel("Latitude", fontsize = 14) 
plt.ylabel("Maximum Temperature (F)", fontsize = 14)
plt.yticks(np.arange(0, 150, 10))

#Save the plot as a graphic
plt.savefig("maximum_temperature_vs_latitude.png", bbox_inches="tight")

#Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Plot the Latitude vs. Humidity Graph
plt.figure(figsize=(10, 8), dpi=80)
plt.scatter(my_weather_df['Lat'],my_weather_df['Humidity'], marker = "o", alpha = 0.75, facecolor = "blue", edgecolors = "black")
plt.title("City Latitude vs. Humidity (07/02/2019 @ 1:00 PM EDT)", fontsize = 18)
plt.xlabel("Latitude", fontsize = 14) 
plt.ylabel("Humidity (%)", fontsize = 14)
plt.yticks(np.arange(0, 110, 10))

#Save the plot as a graphic
plt.savefig("humidity_vs_latitude.png")

#Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Plot the Latitude vs. Cloudiness Graph
plt.figure(figsize=(10, 8), dpi=80)
plt.scatter(my_weather_df['Lat'],my_weather_df['Cloudiness'], marker = "o", alpha = 0.75, facecolor = "blue", edgecolors = "black")
plt.title("City Latitude vs. Cloudiness (07/02/2019 @ 1:00 PM EDT)", fontsize = 18)
plt.xlabel("Latitude", fontsize = 14) 
plt.ylabel("Cloudiness (%)", fontsize = 14)
plt.yticks(np.arange(0, 110, 10))

#Save the plot as a graphic
plt.savefig("cloudiness_vs_latitude.png", bbox_inches="tight")

#Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Plot the Latitude vs. Wind Speed Graph
plt.figure(figsize=(10, 8), dpi=80)
plt.scatter(my_weather_df['Lat'],my_weather_df['Wind Speed'], marker = "o", alpha = 0.75, facecolor = "blue", edgecolors = "black")
plt.title("City Latitude vs. Wind Speed (07/02/2019 @ 1:00 PM EDT)", fontsize = 18)
plt.xlabel("Latitude", fontsize = 14) 
plt.ylabel("Wind Speed (mph)", fontsize = 14)

#Save the plot as a graphic
plt.savefig("wind_speed_vs_latitude.png", bbox_inches="tight")

#Show the plot
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
